# %% [markdown]
# # Installation des dépendances
#
# Pour pouvoir exécuter ce Notebook, l'environnement de développement doit être bien configuré.
#
# <div class="alert alert-info">
#     Pour ce Notebook, on pourra choisir le kernel <code>conda_tensorflow2_p310</code> sur SageMaker.
# </div>

# %%
# !pip install spacy transformers datasets sentencepiece seaborn pandas -q
# !mkdir -p data/
# !wget -q https://blent-keskia.s3.eu-west-3.amazonaws.com/poc/cyberharcelement/mlma.csv -O data/mlma.csv

# %%
# !git lfs install
# !git clone https://huggingface.co/datasets/Paul/hatecheck-french
# Out:
# Error: Failed to call git rev-parse --git-dir: exit status 128
# Git LFS initialized.
# fatal: destination path 'hatecheck-french' already exists and is not an empty directory.

# %% [markdown]
# De même, nous allons utiliser un jeu de données supplémentaire de HuggingFace pour enrichir notre base.

# %% [markdown]
# Enfin, spaCy nous permettra de faire des opérations de traitement du texte adapté à la langue française.

# %%
# !python -m spacy download fr_core_news_sm
# Out:
# 2023-03-25 14:19:45.706432: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-25 14:19:47.203228: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-25 14:19:47.203402: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-25 14:19:47.203433: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fr-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.5.0/fr_core_news_sm-3.5.0-py3-none-any.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 83.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.9/dist-packages (from fr-core-news-sm==3.5.0) (3.5.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (1.10.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (1.0.9)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (1.1.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (0.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (2.27.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (3.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (2.4.6)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (6.3.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (4.65.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (1.22.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (67.6.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->fr-core-news-sm==3.5.0) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')

# %%
import os
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sns.set()

data = pd.read_csv("data/mlma.csv")
hatecheck = pd.read_csv("hatecheck-french/test.csv")

# %% [markdown]
# Ce qui est important pour ce POC, c'est de **différencier ce qui relève de la plaisanterie dans un groupe d'amis d'un harcèlement haineux**. Pour cela, la **notion de contexte sera donc très importante**.
#
# Nous allons considérer les sentiments `normal` et `fearful_normal` comme `non-hateful`, de sorte à harmoniser les labels entre les deux jeux de données.

# %%
data.loc[data["sentiment"] == "normal", "sentiment"] = "non-hateful"
data.loc[data["sentiment"] == "fearful_normal", "sentiment"] = "non-hateful"

# %%
from sklearn.utils import shuffle

# df représente notre DataFrame final du traitement de données
df1 = pd.DataFrame()
df1["Text"] = data["tweet"]
df1["Group"] = data["group"]
df1["Type"] = data["sentiment"]

df2 = pd.DataFrame()
df2["Text"] = hatecheck["test_case"]
df2["Group"] = hatecheck["target_ident"]
df2["Type"] = hatecheck["label_gold"]

df = pd.concat([df1, df2], axis=0)
df = shuffle(df)

# %% [markdown]
# Dans notre cas, nous allons rester sur de la classification binaire.

# %%
df["Type"].loc[(df1["Type"] != "non-hateful")] = "hateful"
df
# Out:
#                                                    Text             Group  \
# 2678  nskslzlzozozozozpeorp brui tah les film star w...             other
# 3804  @user mdr t'es vraiment perdu comme mec t'faço...        individual
# 582   @user @user flagrant délit de militantisme gau...  left_wing_people
# 586   Je vais tirer une balle sur le prochain réfugi...          refugees
# 895   @user mediapart islamo - gauchiste ? c est le ...           muslims
# ...                                                 ...               ...
# 2751  moix c'est un anti tout pro rien une sorte d'a...        individual
# 3322                   J'arrive pas à croire cetravelo.      trans people
# 931             @user oue ils sont tous attarde miskine     special_needs
# 10    #duisburg 4 réfugiés arabes lardent de coups d...             arabs
# 1011  si il une fille j’espère du fond de mon coeur ...             other
#
#              Type
# 2678      hateful
# 3804      hateful
# 582       hateful
# 586       hateful
# 895   non-hateful
# ...           ...
# 2751      hateful
# 3322      hateful
# 931       hateful
# 10        hateful
# 1011      hateful
#
# [7732 rows x 3 columns]

# %% [markdown]
# Là-aussi pour simplifier l'entraînement du modèle, nous allons fusionner certains groupes.

# %%
df["Group"].loc[(df["Group"] == "gay people")] = "gay"
df["Group"].loc[(df["Group"] == "trans people")] = "gay"
df["Group"].loc[(df["Group"] == "black people")] = "african_descent"
df["Group"].loc[(df["Group"] == "Muslims")] = "muslims"
df["Group"].loc[(df["Group"] == "disabled people")] = "special_needs"
df["Group"].loc[(df["Group"] == "refugees")] = "immigrants"
df["Group"].loc[(df["Group"] == "individual")] = "other"

# %% [markdown]
# Regardons à nouveau les groupes uniques.

# %% [markdown]
# # Préparation des données
#
# Tout d'abord, certaines catégories ne sont pas renseignées : dans ce cas, on considérera alors le groupe d'individus `other`.

# %%
df.fillna('other', inplace=True)

# %% [markdown]
# Ensuite, puisque notre modèle n'est capable de ne produire d'une classe en sortie en nond eux classes, nous allons créer artificiellement des classes qui combinent le groupe visé ainsi que le sentiment (haineux ou non).
#
# ### ➡️ À toi de jouer
#
# Créer la colonne `combined` qui combine à la fois le groupe et le type. Par exemple `other non-hateful` ou `women hateful`.

# %%
#df["Combined"] = df["Group"]+" "+df["Type"]
df["Combined"] = df.apply(lambda x: f"{x['Group']} {x['Type']}", axis=1)
df
# Out:
#                                                    Text             Group  \
# 2678  nskslzlzozozozozpeorp brui tah les film star w...             other
# 3804  @user mdr t'es vraiment perdu comme mec t'faço...             other
# 582   @user @user flagrant délit de militantisme gau...  left_wing_people
# 586   Je vais tirer une balle sur le prochain réfugi...        immigrants
# 895   @user mediapart islamo - gauchiste ? c est le ...           muslims
# ...                                                 ...               ...
# 2751  moix c'est un anti tout pro rien une sorte d'a...             other
# 3322                   J'arrive pas à croire cetravelo.               gay
# 931             @user oue ils sont tous attarde miskine     special_needs
# 10    #duisburg 4 réfugiés arabes lardent de coups d...             arabs
# 1011  si il une fille j’espère du fond de mon coeur ...             other
#
#              Type                  Combined
# 2678      hateful             other hateful
# 3804      hateful             other hateful
# 582       hateful  left_wing_people hateful
# 586       hateful        immigrants hateful
# 895   non-hateful       muslims non-hateful
# ...           ...                       ...
# 2751      hateful             other hateful
# 3322      hateful               gay hateful
# 931       hateful     special_needs hateful
# 10        hateful             arabs hateful
# 1011      hateful             other hateful
#
# [7732 rows x 4 columns]

# %% [markdown]
# Maintenant, nous encodons numériquement les classes : cela permettra au modèle de fournir en sortie une probabilité pour chaque classe.
#
# ### ➡️ À toi de jouer
#
# Utiliser un objet `LabelEncoder` de Scikit-Learn pour créer un encodage par dictionnaire et stocker l'encodage de chaque catégorie `combined` dans la colonne `combined_index`.

# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

le = preprocessing.LabelEncoder()

from sklearn.preprocessing import LabelEncoder

# Créer un objet LabelEncoder
le = LabelEncoder()

# Encoder les catégories de la colonne "Combined" en tant que nombres entiers
df['combined_index'] = le.fit_transform(df['Combined'])

# Créer un dictionnaire pour associer chaque catégorie à son index encodé
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))


le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
le_name_mapping
df
# Out:
#                                                    Text             Group  \
# 2678  nskslzlzozozozozpeorp brui tah les film star w...             other
# 3804  @user mdr t'es vraiment perdu comme mec t'faço...             other
# 582   @user @user flagrant délit de militantisme gau...  left_wing_people
# 586   Je vais tirer une balle sur le prochain réfugi...        immigrants
# 895   @user mediapart islamo - gauchiste ? c est le ...           muslims
# ...                                                 ...               ...
# 2751  moix c'est un anti tout pro rien une sorte d'a...             other
# 3322                   J'arrive pas à croire cetravelo.               gay
# 931             @user oue ils sont tous attarde miskine     special_needs
# 10    #duisburg 4 réfugiés arabes lardent de coups d...             arabs
# 1011  si il une fille j’espère du fond de mon coeur ...             other
#
#              Type                  Combined  combined_index
# 2678      hateful             other hateful              22
# 3804      hateful             other hateful              22
# 582       hateful  left_wing_people hateful              18
# 586       hateful        immigrants hateful              12
# 895   non-hateful       muslims non-hateful              21
# ...           ...                       ...             ...
# 2751      hateful             other hateful              22
# 3322      hateful               gay hateful               8
# 931       hateful     special_needs hateful              24
# 10        hateful             arabs hateful               2
# 1011      hateful             other hateful              22
#
# [7732 rows x 5 columns]

# %% [markdown]
# Maintenant, nous allons traiter notre jeu de données car certains mots ne sont pas nécessaires (comme les conjonctions de coordination appelés *stopwords*). Pour cela, nous utilisons la librairie `spacy`.

# %%
import spacy

nlp = spacy.load("fr_core_news_sm")

# %% [markdown]
# ### ➡️ À toi de jouer
#
# Nettoyer la colonne `Text` avec les étapes suivantes.
#
# - Mettre le texte en minuscule et s'assurer qu'il n'y ait pas autre chose que du texte.
# - Retirer les métadonnées propres à Twitter comme `@user` ou `@url`.

# %%
import regex as re

def clean_text(text):
# Mettre le texte en minuscule et s'assurer qu'il n'y ait pas autre chose que du texte.
    text = text.lower()
    text = re.sub(r"[^a-z ]", "", text)
    
    # Retirer les noms d'utilisateur Twitter comme @user.
    text = re.sub(r"@\S+", "", text)
    
    # Retirer les URL commençant par http ou https.
    text = re.sub(r"https?://\S+", "", text)
    
    return text

# Nettoyer la colonne Text en utilisant la fonction clean_text
df["Text"] = df["Text"].apply(clean_text)
df
# Out:
#                                                    Text             Group  \
# 2678  nskslzlzozozozozpeorp brui tah les film star w...             other
# 3804  user mdr tes vraiment perdu comme mec tfaon te...             other
# 582   user user flagrant dlit de militantisme gauchi...  left_wing_people
# 586   je vais tirer une balle sur le prochain rfugi ...        immigrants
# 895   user mediapart islamo  gauchiste  c est le tit...           muslims
# ...                                                 ...               ...
# 2751  moix cest un anti tout pro rien une sorte dado...             other
# 3322                      jarrive pas  croire cetravelo               gay
# 931              user oue ils sont tous attarde miskine     special_needs
# 10    duisburg  rfugis arabes lardent de coups de co...             arabs
# 1011  si il une fille jespre du fond de mon coeur qu...             other
#
#              Type                  Combined  combined_index
# 2678      hateful             other hateful              22
# 3804      hateful             other hateful              22
# 582       hateful  left_wing_people hateful              18
# 586       hateful        immigrants hateful              12
# 895   non-hateful       muslims non-hateful              21
# ...           ...                       ...             ...
# 2751      hateful             other hateful              22
# 3322      hateful               gay hateful               8
# 931       hateful     special_needs hateful              24
# 10        hateful             arabs hateful               2
# 1011      hateful             other hateful              22
#
# [7732 rows x 5 columns]

# %%
re.sub(r"@\S+", "", "@user @user ben toi aussi te dira de te reconver.")
# Out:
# '  ben toi aussi te dira de te reconver.'

# %% [markdown]
# Voyons à quoi notre jeu de données ressemble.

# %%
df.head(n=15)
# Out:
#                                                    Text             Group  \
# 2678  nskslzlzozozozozpeorp brui tah les film star w...             other
# 3804  user mdr tes vraiment perdu comme mec tfaon te...             other
# 582   user user flagrant dlit de militantisme gauchi...  left_wing_people
# 586   je vais tirer une balle sur le prochain rfugi ...        immigrants
# 895   user mediapart islamo  gauchiste  c est le tit...           muslims
# 2757  apres les rebeus nouveau crdo de fink les enfo...             other
# 3199  jai un seul regret mais je mattarde pas dessus...             other
# 2533  les personnes qui menvoient des messages du ty...               gay
# 3211  dans le plus grand des calmes la presse gauchi...             other
# 553   user augmentation des violences proportionnell...      indian/hindu
# 679                                mort  tous les trans               gay
# 1785        nestil pas vident que je dteste les femmes              women
# 3285                je vais vraiment juste tuerce rfugi        immigrants
# 230   seules les femmes sont  ce point violentes et ...             women
# 2066                            je vis avec deux femmes             women
#
#              Type                  Combined  combined_index
# 2678      hateful             other hateful              22
# 3804      hateful             other hateful              22
# 582       hateful  left_wing_people hateful              18
# 586       hateful        immigrants hateful              12
# 895   non-hateful       muslims non-hateful              21
# 2757      hateful             other hateful              22
# 3199  non-hateful         other non-hateful              23
# 2533      hateful               gay hateful               8
# 3211      hateful             other hateful              22
# 553       hateful      indian/hindu hateful              14
# 679       hateful               gay hateful               8
# 1785      hateful             women hateful              26
# 3285      hateful        immigrants hateful              12
# 230       hateful             women hateful              26
# 2066      hateful             women hateful              26

# %% [markdown]
# Pour terminer, on enregistre le jeu de données nettoyé dans le fichier `data_clean.csv` : c'est lui que l'on utilise **pour entraîner le modèle**.

# %%
df.to_csv("data_clean.csv")
df
# Out:
#                                                    Text            Group  \
# 2792  si seulement quelquun pouvait touffer ces init...            other
# 3964                                       user  mongol    special_needs
# 2657  dans ce workshop de lesbos des rfugis dcoupent...            other
# 1280  ces musulmans peuvent ressembler  des tres hum...          muslims
# 1474  ce genre de blacks ne sintgreront jamais on de...  african_descent
# ...                                                 ...              ...
# 3567  user user ben toi aussi te dira de te reconver...            other
# 3700                     trop de mongliens dans ce pays    special_needs
# 3547                     user user regarde le ce mongol            other
# 89    user cest de la violence dont vous tes le produit            other
# 3825  user user es vraiment un mongol c est card c e...            other
#
#              Type                 Combined  combined_index
# 2792      hateful            other hateful              22
# 3964      hateful    special_needs hateful              24
# 2657      hateful            other hateful              22
# 1280      hateful          muslims hateful              20
# 1474      hateful  african_descent hateful               0
# ...           ...                      ...             ...
# 3567  non-hateful        other non-hateful              23
# 3700      hateful    special_needs hateful              24
# 3547      hateful            other hateful              22
# 89    non-hateful        other non-hateful              23
# 3825      hateful            other hateful              22
#
# [7732 rows x 5 columns]
